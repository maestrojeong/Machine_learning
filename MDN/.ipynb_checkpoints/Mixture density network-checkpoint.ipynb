# %% [markdown]
# ## Reference
# [MDN](http://www.cedar.buffalo.edu/~srihari/CSE574/Chap5/Chap5.7-MixDensityNetworks.pdf)

# %%
from utils import *
from NN import *

# %%
num_data = 200

# %%
train_data = {}
train_data['x'] = np.linspace(0,1, num_data)
train_data['y'] = function(train_data['x'])
plotter(train_data['x'], train_data['y'], 'bo')

# %%
train_data2 = {}
train_data2['x'] = train_data['y']
train_data2['y'] = train_data['x']
plotter(train_data2['x'], train_data2['y'], 'bo')

# %%
model2 = Model_MDN(num_data = 200, epoch=200, batch_size = 10, hidden_layers = 150, K = 3)
# Out:
# [<tf.Tensor 'gradients/split_grad/concat:0' shape=(?, 9) dtype=float32>, None, None]

# %%
output = model2.run(train_data2)
# Out:
# cost = -6.624883651733398
# cost = -6.6268792152404785
# cost = -6.627275466918945
# cost = -6.6273417472839355

# %%
print(output['pi'].shape)
# Out:
# (200, 3)

# %%
plt.plot(train_data2['x'], output['pi'][:,0], 'ro')
plt.plot(train_data2['x'], output['pi'][:,1], 'bo')
plt.plot(train_data2['x'], output['pi'][:,2], 'go')
plt.show()
plt.plot(train_data2['x'], output['mu'][:,0], 'ro')
plt.plot(train_data2['x'], output['mu'][:,1], 'bo')
plt.plot(train_data2['x'], output['mu'][:,2], 'go')
plt.show()
plt.plot(train_data2['x'], output['sigma'][:,0], 'ro')
plt.plot(train_data2['x'], output['sigma'][:,1], 'bo')
plt.plot(train_data2['x'], output['sigma'][:,2], 'go')
plt.show()

# %%
model = Model_MSE(num_data=num_data, epoch=200, batch_size = 10, hidden_layers = 150)
train_data['y_hat'] = model.run(train_data)
train_data2['y_hat']=model.run(train_data2)
